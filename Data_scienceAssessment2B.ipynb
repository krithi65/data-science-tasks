# %% [markdown]
# <a href="https://colab.research.google.com/github/krithi65/data-science-tasks/blob/main/Data_scienceAssessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
import pandas as pd

file1 = "/content/college_1.csv"
file2 = "/content/college_2.csv"

print("Merging multiple CSV files...")

# merge
dataFrame = pd.concat(
   map(pd.read_csv, [file1, file2]), ignore_index=True)
dataFrame
# Out:
# Merging multiple CSV files...
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
dataFrame[dataFrame['CodeKata Score']>15000]
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
df1=dataFrame[dataFrame['CodeKata Score']>15000]
df1.to_csv('Exceeded expectations.csv')

# %%
dataFrame.loc[(dataFrame['CodeKata Score'] >10000) & (dataFrame['CodeKata Score']<15000)]
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
df4=dataFrame.loc[(dataFrame['CodeKata Score'] >10000) & (dataFrame['CodeKata Score']<15000)]
df4.to_csv('Reached_expectations.csv')

# %%
dataFrame.loc[(dataFrame['CodeKata Score'] >7000) & (dataFrame['CodeKata Score']<10000)]
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %%
df2=dataFrame.loc[(dataFrame['CodeKata Score'] >7000) & (dataFrame['CodeKata Score']<10000)]
df2.to_csv('Needs_Improvement.csv')

# %%
dataFrame[dataFrame['CodeKata Score']<7000]
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %%
df3=dataFrame[dataFrame['CodeKata Score']<7000]
df3.to_csv('Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
import pandas as pd

file1 = "/content/college_1.csv"
file2 = "/content/college_2.csv"

print("Merging multiple CSV files...")

# merge
dataFrame = pd.concat(
   map(pd.read_csv, [file1, file2]), ignore_index=True)
dataFrame
col_names = ['Previous Geekions', 'CodeKata Score']
# Select multiple columns of dataframe by names in list
multiple_columns = dataFrame[col_names]
print("Selected Columns of Dataframe : ")
multiple_columns
# Out:
# Merging multiple CSV files...
# Selected Columns of Dataframe :
#      Previous Geekions  CodeKata Score
# 0                24500           24500
# 1                21740           21740
# 2                19680           19680
# 3                10610           10610
# 4                 8980            8980
# ..                 ...             ...
# 114               2380            2380
# 115               1890            1890
# 116               1720            1720
# 117                  0               0
# 118                  0               0
#
# [119 rows x 2 columns]

# %% [markdown]
# ###### No of students participated

# %%
dataFrame['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
 dataFrame[["python","mysql","python_en","computational_thinking"]].mean()
# Out:
# python                    54.352941
# mysql                     23.500000
# python_en                 29.657143
# computational_thinking     2.200000
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
dataFrame.nlargest(3, ['CodeKata Score'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
dataFrame.nlargest(3, ['Previous Geekions'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dataFrame.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df=dataFrame.loc[dataFrame['Department'] == 'Computer Science and Engineering',
       ['Name',	'python','mysql'	,'Previous Geekions',	'CodeKata Score',	'Department',	'Rising',	'python_en',	'computational_thinking']].drop_duplicates()
df=df.head(5)
df
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
import matplotlib.pyplot as plt
df.plot(x="Department", y="CodeKata Score", kind="bar", figsize=(10, 9))
plt.show()

# %%
df1=dataFrame.loc[dataFrame['Department'] == 'Electronics and Communication Engineering',
       ['Name',	'python','mysql'	,'Previous Geekions',	'CodeKata Score',	'Department',	'Rising',	'python_en',	'computational_thinking']].drop_duplicates()

df1=df1.head(5)
df1
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 6     KALAIARASAN K    85.0   47.0               7750            7880
# 8        J.SUGANTHI    27.0   50.0               5860            5860
# 10  Iyappan Samiraj    50.0   24.0               5400            5400
# 14  Melvin Dukles.R    56.0   20.0               4800            4800
# 17      v.vithyasri   100.0   12.0               4370            4370
#
#                                    Department  Rising  python_en  \
# 6   Electronics and Communication Engineering     130        NaN
# 8   Electronics and Communication Engineering       0        NaN
# 10  Electronics and Communication Engineering       0        NaN
# 14  Electronics and Communication Engineering       0        NaN
# 17  Electronics and Communication Engineering       0        NaN
#
#     computational_thinking
# 6                      NaN
# 8                      NaN
# 10                     NaN
# 14                     NaN
# ...

# %%
import matplotlib.pyplot as plt
df1.plot(x="Department", y="CodeKata Score", kind="bar", figsize=(10, 9))
plt.show()

# %%
df2=dataFrame.loc[dataFrame['Department'] == 'Electronics and Electrical Engineering',
       ['Name',	'python','mysql'	,'Previous Geekions',	'CodeKata Score',	'Department',	'Rising',	'python_en',	'computational_thinking']].drop_duplicates()
df2=df2.head(5)
df2
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 64       k.parvathi   100.0  100.0                260             260
# 71      m.keerthana    97.5    0.0                120             120
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
#
#                                 Department  Rising  python_en  \
# 64  Electronics and Electrical Engineering       0        NaN
# 71  Electronics and Electrical Engineering       0        NaN
# 72  Electronics and Electrical Engineering       0        NaN
# 74  Electronics and Electrical Engineering       0        NaN
# 75  Electronics and Electrical Engineering       0        NaN
#
#     computational_thinking
# 64                     NaN
# 71                     NaN
# 72                     NaN
# 74                     NaN
# 75                     NaN

# %%
import matplotlib.pyplot as plt
df2.plot(x="Department", y="CodeKata Score", kind="bar", figsize=(10, 9))
plt.show()
